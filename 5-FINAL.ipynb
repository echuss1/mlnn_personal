# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from sklearn import linear_model

# %%
n = 10000
x = np.linspace(0.01, 1, n).reshape(-1, 1)
y = np.linspace(0.01, 1, n)  + np.random.rand(n) - .5


plt.scatter(x,y)

# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## 1. Create and fit a Linear Regression Model
# ## Calculate the Training error and Testing error using sklearn with a .50 split
# For error, use `mean_squared`, but if you want to experiment with other mean errors, please do!

# %%
model= LinearRegression()
model.fit(x[:500], y[:500])
model.coef_, model.intercept_
# Out:
# (array([1.90164331]), -0.037187125573919594)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x,model.coef_) + model.intercept_)

# %%
plt.scatter(x[:500],y[:500])
plt.plot(x[:500], np.dot(x[:500], model.coef_) + model.intercept_)

# %%
def shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return p

# %%
p = shuffle(x, y)

# %%
p
# Out:
# array([8349, 4867, 7776, ..., 9075, 2807, 4911])

# %%
x[p], y[p]
# Out:
# (array([[0.83663366],
#         [0.49188119],
#         [0.77990099],
#         ...,
#         [0.90851485],
#         [0.28792079],
#         [0.49623762]]),
#  array([0.82911864, 0.93803698, 1.00946723, ..., 0.85325909, 0.60769757,
#         0.56167243]))

# %%
plt.scatter(x[p],y[p])

# %%
model = LinearRegression()
model.fit(x[p][:500], y[p][:500])
model.coef_, model.intercept_
# Out:
# (array([0.98756628]), -0.007338253751633661)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %%
x[500:]
# Out:
# array([[0.05950495],
#        [0.05960396],
#        [0.05970297],
#        ...,
#        [0.99980198],
#        [0.99990099],
#        [1.        ]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y[p][500:], np.dot(x[p][500:], model.coef_) + model.intercept_)
# Out:
# 0.0839052218021657

# %% [markdown]
# ## 2.  Repeat #1 for a Ridge Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.5)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([1.00099457]), -0.007324920200704965)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([1.00343985]), -0.008561100269865007)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %%
mean_squared_error(y_test, np.dot(x_test, model.coef_) + model.intercept_)
# Out:
# 0.0831254978695135

# %%
mean_squared_error(y_train, np.dot(x_train, model.coef_) + model.intercept_)
# Out:
# 0.08411865340717802

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
mean_squared_error(y_test, np.dot(x_test, model.coef_) + model.intercept_)
# Out:
# 0.0831254978695135

# %%
mean_squared_error(y_train, np.dot(x_train, model.coef_) + model.intercept_)
# Out:
# 0.08411865340717802

# %% [markdown]
# ## 3. Vary the `split` size from .01 to .99 with at least 10 values (the more the merrier!). Plot the resulting Training error and Testing error vs. `split` size. Create separate plots for Linear and Ridge

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.01)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_

plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.10)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_

plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.99648997]), 0.0008303825746382998)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.45)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.99266303]), 0.0036758251788197027)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.30)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([1.00137286]), 0.0011350146406943207)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.75)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.98500536]), 0.002216741199578043)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.60)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.97193257]), 0.008861328315733608)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.85)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.9979618]), -0.0030101497311684766)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.90)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.98330901]), 0.011307609946766328)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.99)

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_

model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([1.05528512]), -0.02374212640883344)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %% [markdown]
# ## 4. Chose an ideal split size based on the previous plot for Ridge.
# ## Vary the Ridge parameter `alpha` from 0 to any value you'd like above 1. Plot the Train and Test error. Describe what you see based on the `alpha` parameter's stiffness.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.99)

# %%
model = Ridge(alpha=.50)
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([0.98308587]), -0.0351552846399561)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, np.dot(x_train, model.coef_) + model.intercept_)

# %% [markdown]
# ## Bonus. Either: Generate data  with a polynomial shape or use real data that you find on your own. Choose whatever regression model and process you'd like (Ridge, polynomial, etc.) and plot the Train-Test errors vs. any parameter your Model depends on (e.g. `alpha`, `degree`, etc.)
